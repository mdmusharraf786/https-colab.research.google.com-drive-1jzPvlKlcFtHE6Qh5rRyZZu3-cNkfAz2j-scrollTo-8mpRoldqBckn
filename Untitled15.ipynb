# %%
import numpy as np
import pandas as pd
import scipy

# %%
data=pd.read_csv('/content/collegePlace.csv')

# %%
data.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot  AgeSquared  CGPA_Adjusted
# 0                  1            1         484            8.5
# 1                  1            1         441            7.5
# 2                  0            1         484            6.5
# 3                  1            1         441            8.5
# 4                  0            1         484            8.5

# %%
from matplotlib import pyplot as plt
data['Internships'].plot(kind='hist', bins=20, title='Internships')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['Internships'].plot(kind='hist', bins=20, title='Internships')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['CGPA'].plot(kind='hist', bins=20, title='CGPA')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
mean_age = np.mean(data['Age'])
median_age = np.median(data['Age'])
std_age = np.std(data['Age'])

# %%
age_array = data['Age'].to_numpy()
first_10_rows = data.head(10).to_numpy()

# %%
column1_name = 'Age'
column2_name = 'CGPA'

m = data.shape[0]
n = 1
p = m

matrix1 = data[column1_name].to_numpy().reshape(m, n)
matrix2 = data[column2_name].to_numpy().reshape(n, p)

result_matrix = np.dot(matrix1, matrix2)

# %%
print(data.head())
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot  AgeSquared  CGPA_Adjusted
# 0                  1            1         484            8.5
# 1                  1            1         441            7.5
# 2                  0            1         484            6.5
# 3                  1            1         441            8.5
# 4                  0            1         484            8.5

# %%
from matplotlib import pyplot as plt
_df_23['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_24['Internships'].plot(kind='hist', bins=20, title='Internships')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_25['CGPA'].plot(kind='hist', bins=20, title='CGPA')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_26['Hostel'].plot(kind='hist', bins=20, title='Hostel')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_27.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_28.groupby('Stream').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_37['Age'].plot(kind='line', figsize=(8, 4), title='Age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_38['Internships'].plot(kind='line', figsize=(8, 4), title='Internships')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_39['CGPA'].plot(kind='line', figsize=(8, 4), title='CGPA')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_40['Hostel'].plot(kind='line', figsize=(8, 4), title='Hostel')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Stream'].value_counts()
    for x_label, grp in _df_41.groupby('Gender')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Gender')
_ = plt.ylabel('Stream')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Stream'].value_counts()
    for x_label, grp in data.groupby('Gender')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Gender')
_ = plt.ylabel('Stream')
